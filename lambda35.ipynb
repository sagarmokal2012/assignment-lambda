# %%
r = lambda a : a + 25
print(r(10))
# Out:
# 35

# %%
number1 = (1, 2, 3, 4, 5, 6, 7) 
number2 = map(lambda x: x + x + x, number1) 
print("Triple of list numbers:")
print(list(number2))
# Out:
# Triple of list numbers:
# [3, 6, 9, 12, 15, 18, 21]

# %%
def square_num(n):
  return n * n
number_1 = [4, 5, 2, 9]
number_2 = map(square_num, number1)
print(list(number_2))
# Out:
# [16, 25, 4, 81]
